# %%
import os
import sys
import glob
import time
import math
import datetime
import argparse
import numpy as np
import pandas as pd
import scanpy as sc
import pickle as pk
import mindspore as ms
import mindspore.nn as nn
import mindspore.numpy as mnp
import mindspore.scipy as msc
import mindspore.dataset as ds
from tqdm import tqdm,trange
from mindspore import nn,ops
from scipy.sparse import csr_matrix as csr
from mindspore.ops import operations as P
from mindspore.amp import FixedLossScaleManager,all_finite,DynamicLossScaleManager
from mindspore.train import Model, CheckpointConfig, ModelCheckpoint, LossMonitor, Accuracy
from mindspore.context import ParallelMode
from mindspore.communication import init, get_rank, get_group_size
from mindspore.parallel._utils import _get_parallel_mode
from mindspore.common.initializer import initializer, XavierNormal

# %%
sys.path.append('..')
from utils import Wrapper
from config import Config
from metrics import annote_metric
from genefunc_model import *

# %%
class SCrna():
    def __init__(self,path,data,fold,mode):
        self.mode=mode
        adata=sc.read_h5ad(f'{path}/t123.h5ad')
        self.gene_info=pd.read_csv(f'../csv/gene_info.csv',index_col=0,header=0)
        common_gene=np.intersect1d(adata.var_names,self.gene_info.index)
        self.adata=adata[:,common_gene].copy()
        gene=self.adata.var[self.adata.var[f'train_{data}']>-1]
        idx=gene[f'train_{data}']==fold
        self.geneset={j:i+1 for i,j in enumerate(self.gene_info.index)}
        if mode=='train':
            self.gene=np.array([self.geneset[i] for i in gene[~idx].index]).astype(np.int32)
            self.label=gene[f'{data}'][~idx].values
        else:
            self.gene=np.array([self.geneset[i] for i in gene[idx].index]).astype(np.int32)
            self.label=gene[f'{data}'][idx].values
    def __len__(self):
        return len(self.gene)
    def __getitem__(self,idx):
        return self.gene[idx],self.label[idx]

# %%
def build_dataset(
    data,batch,
    mask_rate=0.2,
    drop=True,
    shuffle=True,
    rank_size=None,
    rank_id=None,
):
    dataset = ds.GeneratorDataset(
        data, 
        column_names=["gene",'label'],
        shuffle=shuffle,
        num_shards=rank_size, 
        shard_id=rank_id
    )
    dataset = dataset.batch(
        batch,
        num_parallel_workers=4, 
        drop_remainder=drop, 
    )
    return dataset

# %%
ms.set_context(
    device_target='Ascend', 
    mode=ms.GRAPH_MODE,
    device_id=0,
)
ms.set_seed(0)

# %%
para=ms.load_checkpoint("../weights/base_weight.ckpt")

# %%
cfg=Config()
model=MLP(para['gene_emb'].value(),cfg)
optimizer=nn.Adam(model.trainable_params(),1e-4,weight_decay=1e-5)
wrapper=Wrapper(model,optimizer)
trainer=Model(
    wrapper,
    amp_level='O0',
    eval_network=model,
    metrics={
        'metrics':annote_metric(2),
    },
    eval_indexes=[0,1,2]
)

# %%
acc=[]
for i in range(5):
    print(f"-----------fold {i}-----------")
    scrna=SCrna('../datasets/processed/','t1',fold=i,mode='train')
    trainset=build_dataset(
        scrna,4,
        drop=True
    )
    sctest=SCrna('../datasets/processed/','t1',fold=i,mode='test')
    testset=build_dataset(
        sctest,
        len(sctest),
        drop=False
    )
    loss_cb = LossMonitor(50)
    cbs=[loss_cb]
    trainer.train(30,trainset,callbacks=cbs)
    acc.append(trainer.eval(testset)['metrics'])
print(sum(acc)/5)
# Out:
# -----------fold 0-----------
# epoch: 1 step: 50, loss is 0.6858367919921875
# epoch: 2 step: 15, loss is 0.628882646560669
# epoch: 2 step: 65, loss is 0.5618929862976074
# epoch: 3 step: 30, loss is 0.4210722744464874
# epoch: 3 step: 80, loss is 0.9581413865089417
# epoch: 4 step: 45, loss is 0.3028731644153595
# epoch: 5 step: 10, loss is 0.942497193813324
# epoch: 5 step: 60, loss is 0.7543084621429443
# epoch: 6 step: 25, loss is 0.30059099197387695
# epoch: 6 step: 75, loss is 0.5268030166625977
# epoch: 7 step: 40, loss is 0.3934265673160553
# epoch: 8 step: 5, loss is 0.0921880453824997
# epoch: 8 step: 55, loss is 0.48324501514434814
# epoch: 9 step: 20, loss is 0.30186137557029724
# epoch: 9 step: 70, loss is 0.7508274912834167
# epoch: 10 step: 35, loss is 0.08719252049922943
# epoch: 10 step: 85, loss is 0.7976909279823303
# epoch: 11 step: 50, loss is 0.061052706092596054
# epoch: 12 step: 15, loss is 0.33150607347488403
# epoch: 12 step: 65, loss is 0.06424576044082642
# epoch: 13 step: 30, loss is 0.2368609756231308
# epoch: 13 step: 80, loss is 0.1173725575208664
# epoch: 14 step: 45, loss is 0.05034806951880455
# epoch: 15 step: 10, loss is 0.2194080799818039
# epoch: 15 step: 60, loss is 0.18952104449272156
# epoch: 16 step: 25, loss is 0.394439697265625
# epoch: 16 step: 75, loss is 0.09355282783508301
# epoch: 17 step: 40, loss is 0.7163150310516357
# epoch: 18 step: 5, loss is 0.06461824476718903
# epoch: 18 step: 55, loss is 0.14648211002349854
# epoch: 19 step: 20, loss is 0.042688339948654175
# epoch: 19 step: 70, loss is 0.11593708395957947
# epoch: 20 step: 35, loss is 0.7175788879394531
# epoch: 20 step: 85, loss is 0.08081134408712387
# epoch: 21 step: 50, loss is 0.21896812319755554
# epoch: 22 step: 15, loss is 0.03582290932536125
# epoch: 22 step: 65, loss is 0.04802767559885979
# epoch: 23 step: 30, loss is 0.9413542151451111
# epoch: 23 step: 80, loss is 0.14229583740234375
# epoch: 24 step: 45, loss is 0.3886203169822693
# epoch: 25 step: 10, loss is 0.4507502615451813
# epoch: 25 step: 60, loss is 0.027206124737858772
# epoch: 26 step: 25, loss is 0.08247453719377518
# epoch: 26 step: 75, loss is 0.06943309307098389
# epoch: 27 step: 40, loss is 0.25737035274505615
# epoch: 28 step: 5, loss is 0.02223276160657406
# epoch: 28 step: 55, loss is 0.025464238598942757
# epoch: 29 step: 20, loss is 0.2575432062149048
# epoch: 29 step: 70, loss is 0.05141683667898178
# epoch: 30 step: 35, loss is 0.014014948159456253
# epoch: 30 step: 85, loss is 0.06355088204145432
# {'accuracy': 0.8554216867469879, 'macro f1': 0.7871794871794872, 'weighted f1': 0.8438059932035835, 'macro recall': 0.7563338301043219, 'macro precision': 0.8561076604554865}
# -----------fold 1-----------
# epoch: 1 step: 50, loss is 0.03224274516105652
# epoch: 2 step: 16, loss is 0.04670194908976555
# epoch: 2 step: 66, loss is 0.040706437081098557
# epoch: 3 step: 32, loss is 0.027390863746404648
# epoch: 3 step: 82, loss is 0.14847004413604736
# epoch: 4 step: 48, loss is 0.09073306620121002
# epoch: 5 step: 14, loss is 0.017284641042351723
# epoch: 5 step: 64, loss is 0.020718343555927277
# epoch: 6 step: 30, loss is 0.13046598434448242
# epoch: 6 step: 80, loss is 0.09611091017723083
# epoch: 7 step: 46, loss is 0.02324214205145836
# epoch: 8 step: 12, loss is 0.14467445015907288
# epoch: 8 step: 62, loss is 0.005032638553529978
# epoch: 9 step: 28, loss is 0.5480194687843323
# epoch: 9 step: 78, loss is 0.5474324822425842
# epoch: 10 step: 44, loss is 0.05856144055724144
# epoch: 11 step: 10, loss is 0.018381282687187195
# epoch: 11 step: 60, loss is 0.008851105347275734
# epoch: 12 step: 26, loss is 0.01072566956281662
# epoch: 12 step: 76, loss is 0.015927642583847046
# epoch: 13 step: 42, loss is 0.011248717084527016
# epoch: 14 step: 8, loss is 0.08398357033729553
# epoch: 14 step: 58, loss is 0.007822784595191479
# epoch: 15 step: 24, loss is 0.03196113556623459
# epoch: 15 step: 74, loss is 0.00610441854223609
# epoch: 16 step: 40, loss is 0.2441941797733307
# epoch: 17 step: 6, loss is 0.004202472977340221
# epoch: 17 step: 56, loss is 0.013586755841970444
# epoch: 18 step: 22, loss is 0.00487041799351573
# epoch: 18 step: 72, loss is 0.7084169387817383
# epoch: 19 step: 38, loss is 0.029882285743951797
# epoch: 20 step: 4, loss is 0.002851111814379692
# epoch: 20 step: 54, loss is 0.011691141873598099
# epoch: 21 step: 20, loss is 0.00908232107758522
# epoch: 21 step: 70, loss is 0.0036634192802011967
# epoch: 22 step: 36, loss is 0.06458867341279984
# epoch: 23 step: 2, loss is 0.08483525365591049
# epoch: 23 step: 52, loss is 0.007227854337543249
# epoch: 24 step: 18, loss is 0.011151611804962158
# epoch: 24 step: 68, loss is 0.15226095914840698
# epoch: 25 step: 34, loss is 0.04639004170894623
# epoch: 25 step: 84, loss is 0.014941403642296791
# epoch: 26 step: 50, loss is 0.008863767609000206
# epoch: 27 step: 16, loss is 0.04834161698818207
# epoch: 27 step: 66, loss is 0.008576520718634129
# epoch: 28 step: 32, loss is 0.013605809770524502
# epoch: 28 step: 82, loss is 0.0009829651098698378
# epoch: 29 step: 48, loss is 0.002244302537292242
# epoch: 30 step: 14, loss is 0.15280145406723022
# epoch: 30 step: 64, loss is 0.0096775833517313
# {'accuracy': 0.9764705882352941, 'macro f1': 0.9683779761904762, 'weighted f1': 0.9760941876750701, 'macro recall': 0.9545454545454546, 'macro precision': 0.9846153846153847}
# -----------fold 2-----------
# epoch: 1 step: 50, loss is 0.030009815469384193
# epoch: 2 step: 16, loss is 0.0069260140880942345
# epoch: 2 step: 66, loss is 0.0679638683795929
# epoch: 3 step: 32, loss is 0.010111701674759388
# epoch: 3 step: 82, loss is 0.011706245131790638
# epoch: 4 step: 48, loss is 0.0037077651359140873
# epoch: 5 step: 14, loss is 0.008626860566437244
# epoch: 5 step: 64, loss is 0.0641249492764473
# epoch: 6 step: 30, loss is 0.2531804144382477
# epoch: 6 step: 80, loss is 0.02230807952582836
# epoch: 7 step: 46, loss is 0.0228499174118042
# epoch: 8 step: 12, loss is 0.013219420798122883
# epoch: 8 step: 62, loss is 0.020206047222018242
# epoch: 9 step: 28, loss is 0.0006579739274457097
# epoch: 9 step: 78, loss is 0.006654216907918453
# epoch: 10 step: 44, loss is 0.02607218734920025
# epoch: 11 step: 10, loss is 0.0035701461602002382
# epoch: 11 step: 60, loss is 0.07557305693626404
# epoch: 12 step: 26, loss is 0.08776050806045532
# epoch: 12 step: 76, loss is 0.008753377944231033
# epoch: 13 step: 42, loss is 0.00048606135533191264
# epoch: 14 step: 8, loss is 0.0024632448330521584
# epoch: 14 step: 58, loss is 0.1335325837135315
# epoch: 15 step: 24, loss is 0.34677654504776
# epoch: 15 step: 74, loss is 0.21640545129776
# epoch: 16 step: 40, loss is 0.034240759909152985
# epoch: 17 step: 6, loss is 0.047670621424913406
# epoch: 17 step: 56, loss is 0.02174021489918232
# epoch: 18 step: 22, loss is 0.04061689227819443
# epoch: 18 step: 72, loss is 0.004498231690376997
# epoch: 19 step: 38, loss is 0.00498188566416502
# epoch: 20 step: 4, loss is 0.05248747766017914
# epoch: 20 step: 54, loss is 0.01095922663807869
# epoch: 21 step: 20, loss is 0.007582271937280893
# epoch: 21 step: 70, loss is 0.03408369421958923
# epoch: 22 step: 36, loss is 0.001054876483976841
# epoch: 23 step: 2, loss is 0.0368855744600296
# epoch: 23 step: 52, loss is 0.08329521864652634
# epoch: 24 step: 18, loss is 0.0770399197936058
# epoch: 24 step: 68, loss is 0.004625717643648386
# epoch: 25 step: 34, loss is 0.0038876233156770468
# epoch: 25 step: 84, loss is 0.008004995994269848
# epoch: 26 step: 50, loss is 0.006706205662339926
# epoch: 27 step: 16, loss is 0.0028450675308704376
# epoch: 27 step: 66, loss is 0.0064568896777927876
# epoch: 28 step: 32, loss is 0.03929299861192703
# epoch: 28 step: 82, loss is 0.013389380648732185
# epoch: 29 step: 48, loss is 0.0006804221775382757
# epoch: 30 step: 14, loss is 0.01808825135231018
# epoch: 30 step: 64, loss is 0.031148815527558327
# {'accuracy': 1.0, 'macro f1': 1.0, 'weighted f1': 1.0, 'macro recall': 1.0, 'macro precision': 1.0}
# -----------fold 3-----------
# epoch: 1 step: 50, loss is 0.03870175778865814
# epoch: 2 step: 16, loss is 0.04083293676376343
# epoch: 2 step: 66, loss is 0.032807134091854095
# epoch: 3 step: 32, loss is 0.009075850248336792
# epoch: 3 step: 82, loss is 0.017064101994037628
# epoch: 4 step: 48, loss is 0.0015752380713820457
# epoch: 5 step: 14, loss is 0.03222927078604698
# epoch: 5 step: 64, loss is 0.00010440709593240172
# epoch: 6 step: 30, loss is 0.00014241841563489288
# epoch: 6 step: 80, loss is 0.0018306466517969966
# epoch: 7 step: 46, loss is 0.002415912924334407
# epoch: 8 step: 12, loss is 0.012079592794179916
# epoch: 8 step: 62, loss is 0.020538531243801117
# epoch: 9 step: 28, loss is 0.15208300948143005
# epoch: 9 step: 78, loss is 0.029767489060759544
# epoch: 10 step: 44, loss is 0.0060990434139966965
# epoch: 11 step: 10, loss is 0.0005721845664083958
# epoch: 11 step: 60, loss is 0.0020746972877532244
# epoch: 12 step: 26, loss is 0.00178316212259233
# epoch: 12 step: 76, loss is 0.0007961769588291645
# epoch: 13 step: 42, loss is 0.0005059363902546465
# epoch: 14 step: 8, loss is 0.014478756114840508
# epoch: 14 step: 58, loss is 0.00020316967857070267
# epoch: 15 step: 24, loss is 0.016111772507429123
# epoch: 15 step: 74, loss is 0.04359831660985947
# epoch: 16 step: 40, loss is 0.0399576872587204
# epoch: 17 step: 6, loss is 0.00027884627343155444
# epoch: 17 step: 56, loss is 0.0010787168284878135
# epoch: 18 step: 22, loss is 3.307843871880323e-05
# epoch: 18 step: 72, loss is 0.0010330090299248695
# epoch: 19 step: 38, loss is 0.0033129281364381313
# epoch: 20 step: 4, loss is 0.37211382389068604
# epoch: 20 step: 54, loss is 0.0009578684694133699
# epoch: 21 step: 20, loss is 0.025754734873771667
# epoch: 21 step: 70, loss is 0.0028658381197601557
# epoch: 22 step: 36, loss is 0.02873740717768669
# epoch: 23 step: 2, loss is 0.0017455552006140351
# epoch: 23 step: 52, loss is 0.02045947127044201
# epoch: 24 step: 18, loss is 0.0023717114236205816
# epoch: 24 step: 68, loss is 0.00028157522319816053
# epoch: 25 step: 34, loss is 0.0071075912564992905
# epoch: 25 step: 84, loss is 0.0018140176543965936
# epoch: 26 step: 50, loss is 0.014463424682617188
# epoch: 27 step: 16, loss is 0.001828217413276434
# epoch: 27 step: 66, loss is 0.02495359070599079
# epoch: 28 step: 32, loss is 0.006673378404229879
# epoch: 28 step: 82, loss is 0.002572270343080163
# epoch: 29 step: 48, loss is 0.0016040342161431909
# epoch: 30 step: 14, loss is 0.004297827370464802
# epoch: 30 step: 64, loss is 0.048475053161382675
# {'accuracy': 1.0, 'macro f1': 1.0, 'weighted f1': 1.0, 'macro recall': 1.0, 'macro precision': 1.0}
# -----------fold 4-----------
# epoch: 1 step: 50, loss is 0.003628348233178258
# epoch: 2 step: 16, loss is 0.009182913228869438
# epoch: 2 step: 66, loss is 0.0002960490819532424
# epoch: 3 step: 32, loss is 0.0021396654192358255
# epoch: 3 step: 82, loss is 0.002072191098704934
# epoch: 4 step: 48, loss is 0.010404729284346104
# epoch: 5 step: 14, loss is 0.0008950586197897792
# epoch: 5 step: 64, loss is 0.031679246574640274
# epoch: 6 step: 30, loss is 0.00511405011638999
# epoch: 6 step: 80, loss is 0.0005407188436947763
# epoch: 7 step: 46, loss is 0.0006599181797355413
# epoch: 8 step: 12, loss is 0.002033641329035163
# epoch: 8 step: 62, loss is 0.0005866684368811548
# epoch: 9 step: 28, loss is 0.003619554452598095
# epoch: 9 step: 78, loss is 0.008091582916676998
# epoch: 10 step: 44, loss is 0.005986187607049942
# epoch: 11 step: 10, loss is 0.0013956233160570264
# epoch: 11 step: 60, loss is 0.0002982392907142639
# epoch: 12 step: 26, loss is 0.0019259362015873194
# epoch: 12 step: 76, loss is 0.0023425999097526073
# epoch: 13 step: 42, loss is 0.00015299810911528766
# epoch: 14 step: 8, loss is 0.0018804871942847967
# epoch: 14 step: 58, loss is 0.0034327784087508917
# epoch: 15 step: 24, loss is 0.0006070798262953758
# epoch: 15 step: 74, loss is 0.007611932698637247
# epoch: 16 step: 40, loss is 9.413109364686534e-05
# epoch: 17 step: 6, loss is 0.00038882726221345365
# epoch: 17 step: 56, loss is 0.006713805720210075
# epoch: 18 step: 22, loss is 0.0009213276789523661
# epoch: 18 step: 72, loss is 0.03798189386725426
# epoch: 19 step: 38, loss is 0.0003538848541211337
# epoch: 20 step: 4, loss is 0.0031653200276196003
# epoch: 20 step: 54, loss is 0.00031097192550078034
# epoch: 21 step: 20, loss is 0.0037739230319857597
# epoch: 21 step: 70, loss is 0.004921626765280962
# epoch: 22 step: 36, loss is 0.0006250330479815602
# epoch: 23 step: 2, loss is 0.005063360556960106
# epoch: 23 step: 52, loss is 0.0018953707767650485
# epoch: 24 step: 18, loss is 9.294445771956816e-05
# epoch: 24 step: 68, loss is 0.0050867777317762375
# epoch: 25 step: 34, loss is 0.0008412415627390146
# epoch: 25 step: 84, loss is 3.882993769366294e-05
# epoch: 26 step: 50, loss is 0.0013807532377541065
# epoch: 27 step: 16, loss is 0.009919772855937481
# epoch: 27 step: 66, loss is 0.0012757006334140897
# epoch: 28 step: 32, loss is 6.815400411142036e-05
# epoch: 28 step: 82, loss is 0.0007480781641788781
# epoch: 29 step: 48, loss is 0.0032379801850765944
# epoch: 30 step: 14, loss is 0.01152518019080162
# epoch: 30 step: 64, loss is 0.0002548892516642809
# {'accuracy': 0.9764705882352941, 'macro f1': 0.9683779761904762, 'weighted f1': 0.9760941876750701, 'macro recall': 0.9545454545454546, 'macro precision': 0.9846153846153847}
# 0.9616725726435152
